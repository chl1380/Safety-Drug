# %%
import numpy as np
import networkx as nx
import scipy.sparse as sp
import sys
from sklearn import metrics
from collections import defaultdict


def load_dictionary(fname='C:\\Users\\chl13\\Desktop\\연결을위한약.csv'):
    fin = open(fname)
    print('Reading: %s' % fname)
    stitch_idx = defaultdict(set)
    stitch_reidx = defaultdict(set)
    fin.readline()
    stitch_list = []
    for line in fin:
        stitch_id = line.strip()
        stitch_list += [[stitch_id]]
    node1 = list(set([u for e in stitch_list for u in e]))
    for i in range(len(node1)):
        stitch_idx[node1[i]] = i
        stitch_reidx[i] = node1[i]
    return stitch_idx, stitch_reidx, node1

def load_mat(fname='C:\\Users\\chl13\\Desktop\\연결.csv'):
    stitch2proteins = defaultdict(set)
    edges3 = []
    medi_gene_adj = np.zeros((8546,8546))
    fin = open(fname)
    print('Reading: %s' % fname)
    fin.readline()
    for line in fin:
        stitch_id, stitch2_id = line.strip().split(',')
        medi_gene_adj[stitch_dict[stitch_id], stitch_dict[stitch2_id]] = 1
        medi_gene_adj[stitch_dict[stitch2_id], stitch_dict[stitch_id]] = 1
    return medi_gene_adj

# %%
fin2 = open('C:\\Users\\chl13\\Desktop\\pre_drug_drug2.csv')
fin2.readline()
stitch_dict, stitch_redict, node1 = load_dictionary()
drug_drug_adj = load_mat()
drug_drug_adj2 = drug_drug_adj.dot(drug_drug_adj)
drug_drug_adj3 = drug_drug_adj2.dot(drug_drug_adj)
drug_drug_adj4 = drug_drug_adj3.dot(drug_drug_adj)
drug_drug_adj5 = drug_drug_adj4.dot(drug_drug_adj)
drug_drug_adj6 = drug_drug_adj5.dot(drug_drug_adj)
drug_drug_adj7 = drug_drug_adj6.dot(drug_drug_adj)
drug_drug_adj8 = drug_drug_adj7.dot(drug_drug_adj)
drug_drug_adj9 = drug_drug_adj8.dot(drug_drug_adj)
drug_drug_adj10 = drug_drug_adj9.dot(drug_drug_adj)
drug_drug_adj11 = drug_drug_adj10.dot(drug_drug_adj)
drug_drug_adj12 = drug_drug_adj11.dot(drug_drug_adj)
drug_drug_adj13 = drug_drug_adj12.dot(drug_drug_adj)
drug_drug_adj14 = drug_drug_adj13.dot(drug_drug_adj)
drug_drug_adj15 = drug_drug_adj14.dot(drug_drug_adj)
drug_drug_adj16 = drug_drug_adj15.dot(drug_drug_adj)
drug_drug_adj17 = drug_drug_adj16.dot(drug_drug_adj)
drug_drug_adj18 = drug_drug_adj17.dot(drug_drug_adj)
# Out:
# Reading: C:\Users\chl13\Desktop\연결을위한약.csv
# Reading: C:\Users\chl13\Desktop\연결.csv

# %%
for line in fin2:
    A, B = line.strip().split(',')
    print("")
    print(A, B)
    if drug_drug_adj2[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj[stitch_dict[A], i] != 0:
                print(A, stitch_redict[i], B)
                break
    elif drug_drug_adj3[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj2[stitch_dict[A], i] !=0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj[stitch_dict[A], j] != 0:
                print(A, stitch_redict[j], stitch_redict[bet], B)
                break
    elif drug_drug_adj4[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj3[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj2[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj[stitch_dict[A], k] != 0:
                print(A, stitch_redict[k],stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj5[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj4[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj3[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj2[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj[stitch_dict[A], n] != 0:
                print(A, stitch_redict[n],stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj6[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj5[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj4[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj3[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj2[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj[stitch_dict[A], m] != 0:
                print(A, stitch_redict[m],stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj7[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj6[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj5[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj4[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj3[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj2[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj[stitch_dict[A], o] != 0:
                print(A, stitch_redict[o],stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj8[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj7[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj6[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj5[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj4[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj3[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj2[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj[stitch_dict[A], p] != 0:
                print(A, stitch_redict[p],stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj9[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj8[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj7[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj6[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj5[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj4[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj3[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj2[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj[stitch_dict[A], q] != 0:
                print(A, stitch_redict[q], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj10[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj9[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj8[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj7[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj6[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj5[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj4[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj3[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj2[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj[stitch_dict[A], r] != 0:
                print(A, stitch_redict[r], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj11[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj10[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj9[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj8[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj7[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj6[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj5[stitch_dict[A], n] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj4[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj3[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj2[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj[stitch_dict[A], s] != 0:
                print(A, stitch_redict[s], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj12[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj11[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj10[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj9[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj8[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj7[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj6[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj5[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj4[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj3[stitch_dict[A], i] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj2[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj[stitch_dict[A], t] != 0:
                print(A, stitch_redict[t], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj13[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj12[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj11[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj10[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj9[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj8[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj7[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj6[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj5[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj4[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj3[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj2[stitch_dict[A], t] != 0:
                bet11 = t
                break
        for u in range(8546):
            if drug_drug_adj[bet11, u] == 1 and drug_drug_adj[stitch_dict[A], u] != 0:
                print(A, stitch_redict[u], stitch_redict[bet11], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj14[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj13[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj12[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj11[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj10[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj9[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj8[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj7[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj6[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj5[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj4[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj3[stitch_dict[A], t] != 0:
                bet11 = t
                break
        for u in range(8546):
            if drug_drug_adj[bet11, u] == 1 and drug_drug_adj2[stitch_dict[A], u] != 0:
                bet12 = u
                break
        for v in range(8546):
            if drug_drug_adj[bet12, v] == 1 and drug_drug_adj[stitch_dict[A], v] != 0:
                print(A, stitch_redict[v], stitch_redicg[bet12], stitch_redict[bet11], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj15[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj14[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj13[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj12[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj11[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj10[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj9[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj8[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj7[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj6[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj5[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj4[stitch_dict[A], t] != 0:
                bet11 = t
                break
        for u in range(8546):
            if drug_drug_adj[bet11, u] == 1 and drug_drug_adj3[stitch_dict[A], u] != 0:
                bet12 = u
                break
        for v in range(8546):
            if drug_drug_adj[bet12, v] == 1 and drug_drug_adj2[stitch_dict[A], v] != 0:
                bet13 = v
                break
        for w in range(8546):
            if drug_drug_adj[bet13, w] == 1 and drug_drug_adj[stitch_dict[A], w] != 0:
                print(A, stitch_redict[w], stitch_redict[bet13], stitch_redicg[bet12], stitch_redict[bet11], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj16[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj15[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj14[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj13[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj12[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj11[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj10[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj9[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj8[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj7[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj6[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj5[stitch_dict[A], t] != 0:
                bet11 = t
                break
        for u in range(8546):
            if drug_drug_adj[bet11, u] == 1 and drug_drug_adj4[stitch_dict[A], u] != 0:
                bet12 = u
                break
        for v in range(8546):
            if drug_drug_adj[bet12, v] == 1 and drug_drug_adj3[stitch_dict[A], v] != 0:
                bet13 = v
                break
        for w in range(8546):
            if drug_drug_adj[bet13, w] == 1 and drug_drug_adj2[stitch_dict[A], w] != 0:
                bet14 = w
                break
        for x in range(8546):
            if drug_drug_adj[bet14, x] == 1 and drug_drug_adj[stitch_dict[A], x] != 0:
                print(A, stitch_redict[x], stitch_redict[bet14], stitch_redict[bet13], stitch_redicg[bet12], stitch_redict[bet11], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj17[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj16[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj15[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj14[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj13[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj12[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj11[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj10[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj9[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj8[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj7[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj6[stitch_dict[A], t] != 0:
                bet11 = t
                break
        for u in range(8546):
            if drug_drug_adj[bet11, u] == 1  and drug_drug_adj5[stitch_dict[A], u] != 0:
                bet12 = u
                break
        for v in range(8546):
            if drug_drug_adj[bet12, v] == 1 and drug_drug_adj4[stitch_dict[A], v] != 0:
                bet13 = v
                break
        for w in range(8546):
            if drug_drug_adj[bet13, w] == 1 and drug_drug_adj3[stitch_dict[A], w] != 0:
                bet14 = w
                break
        for x in range(8546):
            if drug_drug_adj[bet14, x] == 1 and drug_drug_adj2[stitch_dict[A], x] != 0:
                bet15 = x
                break
        for y in range(8546):
            if drug_drug_adj[bet15, y] == 1 and drug_drug_adj[stitch_dict[A], y] != 0:
                print(A, stitch_redict[y], stitch_redict[bet15], stitch_redict[bet14], stitch_redict[bet13], stitch_redicg[bet12], stitch_redict[bet11], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
    elif drug_drug_adj18[stitch_dict[A], stitch_dict[B]] != 0:
        for i in range(8546):
            if drug_drug_adj[stitch_dict[B], i] == 1 and drug_drug_adj17[stitch_dict[A], i] != 0:
                bet = i
                break
        for j in range(8546):
            if drug_drug_adj[bet, j] == 1 and drug_drug_adj16[stitch_dict[A], j] != 0:
                bet2 = j
                break
        for k in range(8546):
            if drug_drug_adj[bet2, k] == 1 and drug_drug_adj15[stitch_dict[A], k] != 0:
                bet3 = k
                break
        for n in range(8546):
            if drug_drug_adj[bet3, n] == 1 and drug_drug_adj14[stitch_dict[A], n] != 0:
                bet4 = n
                break
        for m in range(8546):
            if drug_drug_adj[bet4, m] == 1 and drug_drug_adj13[stitch_dict[A], m] != 0:
                bet5 = m
                break
        for o in range(8546):
            if drug_drug_adj[bet5, o] == 1 and drug_drug_adj12[stitch_dict[A], o] != 0:
                bet6 = o
                break
        for p in range(8546):
            if drug_drug_adj[bet6, p] == 1 and drug_drug_adj11[stitch_dict[A], p] != 0:
                bet7 = p
                break
        for q in range(8546):
            if drug_drug_adj[bet7, q] == 1 and drug_drug_adj10[stitch_dict[A], q] != 0:
                bet8 = q
                break
        for r in range(8546):
            if drug_drug_adj[bet8, r] == 1 and drug_drug_adj9[stitch_dict[A], r] != 0:
                bet9 = r
                break
        for s in range(8546):
            if drug_drug_adj[bet9, s] == 1 and drug_drug_adj8[stitch_dict[A], s] != 0:
                bet10 = s
                break
        for t in range(8546):
            if drug_drug_adj[bet10, t] == 1 and drug_drug_adj7[stitch_dict[A], t] != 0:
                bet11 = t
                break
        for u in range(8546):
            if drug_drug_adj[bet11, u] == 1 and drug_drug_adj6[stitch_dict[A], u] != 0:
                bet12 = u
                break
        for v in range(8546):
            if drug_drug_adj[bet12, v] == 1 and drug_drug_adj5[stitch_dict[A], v] != 0:
                bet13 = v
                break
        for w in range(8546):
            if drug_drug_adj[bet13, w] == 1 and drug_drug_adj4[stitch_dict[A], w] != 0:
                bet14 = w
                break
        for x in range(8546):
            if drug_drug_adj[bet14, x] == 1 and drug_drug_adj3[stitch_dict[A], x] != 0:
                bet15 = x
                break
        for y in range(8546):
            if drug_drug_adj[bet15, y] == 1 and drug_drug_adj2[stitch_dict[A], y] != 0:
                bet16 = y
                break
        for z in range(8546):
            if drug_drug_adj[bet16, z] == 1 and drug_drug_adj[stitch_dict[A], z] != 0:
                print(A, stitch_redict[z], stitch_redict[bet16], stitch_redict[bet15], stitch_redict[bet14], stitch_redict[bet13], stitch_redicg[bet12], stitch_redict[bet11], stitch_redict[bet10], stitch_redict[bet9], stitch_redict[bet8], stitch_redict[bet7], stitch_redict[bet6], stitch_redict[bet5], stitch_redict[bet4], stitch_redict[bet3], stitch_redict[bet2], stitch_redict[bet], B)
                break
# Out:
# 리납틴듀오정2.5/500밀리그램 제로시드정20/1100밀리그램
#
# 콤비글라이즈서방정5/1000밀리그램 엑스비라정
#
# 안제메트주사 아미로정
# 안제메트주사 멀택정 다비트란캡슐110밀리그램 임프란타연질캡슐100밀리그램 타크로민캡슐1밀리그램 아미로정
#
# 비키라정 순베프라캡슐100밀리그램
#
# 록스펜주 코러스오메프라졸캡슐10mg
# 록스펜주 유니온케토롤락주 구주케토프로펜주사액 시프론정 신일돔페리돈정 레야타즈캡슐150밀리그램 코러스오메프라졸캡슐10mg
#
# 코오롱브렉신정10밀리그램 판베시서방캡슐30밀리그램
# 코오롱브렉신정10밀리그램 유니온케토롤락주 구주케토프로펜주사액 시프론정 신일돔페리돈정 이팍신서방캡슐75밀리그램 마오비정 판베시서방캡슐30밀리그램
#
# 베믈리디정 제피드정200밀리그램
# 베믈리디정 아세비라정10mg 데스코비정200/10mg 리벅스정 젠보야정 제피드정200밀리그램
#
# 트리멕정 이미실키트주사250밀리그람
#
# 사이폴-엔연질캡슐50밀리그램 스타레보필름코팅정125/31.25/200밀리그램
# 사이폴-엔연질캡슐50밀리그램 제이에스심바스타틴정20mg 클라리움건조시럽125mg/5mL 페리돌정5밀리그램 스타레보필름코팅정125/31.25/200밀리그램
#
# 싸이문주 알엠서방정750/5밀리그램
#
# 테넬리아엠서방정20/1000밀리그램 아그레녹스서방캡슐
#
# 쎄글루로메트정7.5/500밀리그램 밀타오디정7.5mg
#
# 이미실키트주사250밀리그람 디어미순정
#
# 테포비어정 타크롤캡슐1밀리그램
# 테포비어정 아세비라정10mg 데스코비정200/10mg 리벅스정 젠보야정 제이에스심바스타틴정20mg 임프란타연질캡슐100밀리그램 타크롤캡슐1밀리그램
#
# 슈프라제정 멜로텍스캡슐15mg
# 슈프라제정 신일돔페리돈정 시프론정 구주케토프로펜주사액 유니온케토롤락주 멜로텍스캡슐15mg
#
# 보스민액 테노퀄정
# 보스민액 페리돌정5밀리그램 코다론주사 젠보야정 리벅스정 데스코비정200/10mg 아세비라정10mg 테노퀄정
#
# ...
